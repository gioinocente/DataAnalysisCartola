# %%
import pandas as pd

# %%
rodada = '1'
atacantes = pd.read_csv('Dados/Atacante/'+rodada+'.csv')

# %%
atacantes
# Out:
#              apelido         clube   posicao  preco  pontos  variacao  media  \
# 0            Helinho    Bragantino  Atacante  13.92    15.0      8.92   15.0
# 1         Zé Roberto   Atlético-GO  Atacante  10.79     9.5      4.79    9.5
# 2      Renato Kayzer  Athlético-PR  Atacante   9.96     3.3     -1.04    3.3
# 3           Gilberto         Bahia  Atacante   4.39     1.3     -0.61    1.3
# 4      Eduardo Sasha   Atlético-MG  Atacante   7.00     0.0      0.00    0.0
# ..               ...           ...       ...    ...     ...       ...    ...
# 188           Ângelo        Santos  Atacante   1.95    -0.2     -1.05   -0.2
# 189       Luan Silva     Palmeiras  Atacante   2.00     0.0      0.00    0.0
# 190           Marino     Palmeiras  Atacante   1.00     0.0      0.00    0.0
# 191           Raniel        Santos  Atacante   5.00     0.0      0.00    0.0
# 192  Rodrigo Varanda   Corinthians  Atacante   3.00     0.0      0.00    0.0
#
#      jogos
# 0        1
# 1        1
# ...
